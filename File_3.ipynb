# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('Final_data.csv')

# %%
import lightgbm as lgb

# %%
data
# Out:
#      Unnamed: 0        Date  Piligrims  Tonsures  Hundi  Speciality  \
# 0             0  2022-01-01      36560     14084   2.15           5
# 1             1  2022-02-01      38894     12270   3.93           4
# 2             2  2022-03-01      31776     16046   2.69           5
# 3             3  2022-04-01      31523     14692   2.45           4
# 4             4  2022-05-01      32044     17558   2.61           5
# ..          ...         ...        ...       ...    ...         ...
# 360         360  27/12/2022      70496     25500   5.88           0
# 361         361  28/12/2022      71299     28288   3.26           0
# 362         362  29/12/2022      67156     24752   4.92           0
# 363         363  30/12/2022      63253     24490   5.16           0
# 364         364  31/12/2022      71069     34741   4.98           0
#
#      Temperature  Condition  ttd online darshan tickets  Tirupati  ...  \
# 0             77       1275                           0        43  ...
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Piligrims', 'Tonsures', 'Hundi', 'Speciality',
#        'Temperature', 'Condition', 'ttd online darshan tickets', 'Tirupati',
#        'Tirumala', 'VIP darshan', 'How to reach Tirupati',
#        'ttd sarva darshan tickets',
#        'ttd free darshan online booking availability',
#        'apsrtc tirumala darshan tickets', 'apsrtc ttd 300 tickets',
#        'ksrtc tirupati package', 'srinivasam complex',
#        'tirumala darshan tickets', 'tirumala darshan',
#        'tirupati balaji.ap.gov.in', 'tirupati darshan 500 rupees ticket',
#        'ttd free darshan online booking availability.1', 'Week_day', 'Review',
#        'Timestamp'],
#       dtype='object')

# %%
x_train,x_test,y_train,y_test=train_test_split(data[['Temperature', 'ttd online darshan tickets', 'Tirupati',
       'Tirumala', 'VIP darshan', 'How to reach Tirupati',
       'ttd sarva darshan tickets',
       'ttd free darshan online booking availability',
       'apsrtc tirumala darshan tickets', 'apsrtc ttd 300 tickets',
       'ksrtc tirupati package', 'srinivasam complex',
       'tirumala darshan tickets', 'tirumala darshan',
       'tirupati balaji.ap.gov.in', 'tirupati darshan 500 rupees ticket',
       'ttd free darshan online booking availability.1']],data['Piligrims'],test_size=0.28,random_state=42)

# %%
model=lgb.LGBMRegressor()
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000458 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 470
# [LightGBM] [Info] Number of data points in the train set: 262, number of used features: 17
# [LightGBM] [Info] Start training from score 65665.335878
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
model.score(x_train,y_train)
# Out:
# 0.9228220538534492

# %%
from sklearn import preprocessing

# %%
scaler=preprocessing.StandardScaler()

# %%
x_proc=scaler.fit_transform(x_train)

# %%
x_proc
# Out:
# array([[-5.23049900e-01,  8.84360681e-01,  7.95737076e-01, ...,
#          1.13212889e+00, -5.40182898e-01, -6.54702551e-01],
#        [ 1.32639448e-01, -4.05263614e-01,  2.76476518e-01, ...,
#         -4.55035728e-04, -5.40182898e-01, -6.54702551e-01],
#        [ 1.28009581e+00, -4.76909409e-01, -5.02414318e-01, ...,
#         -4.17722799e-01, -5.40182898e-01,  1.25120932e+00],
#        ...,
#        [-6.86972237e-01, -7.63492585e-01, -6.96971868e-02, ...,
#          1.48978697e+00,  7.16808490e-01, -6.54702551e-01],
#        [-1.34266159e+00, -4.70346435e-02,  1.03389666e-01, ...,
#         -7.15771200e-01, -5.40182898e-01, -6.54702551e-01],
#        [ 6.24406460e-01, -7.63492585e-01,  1.03389666e-01, ...,
#         -7.15771200e-01,  1.74102370e+00,  2.06031842e-01]])

# %%
x_test_proc=scaler.transform(x_test)

# %%
model=lgb.LGBMRegressor()
model.fit(x_proc,y_train)
model.score(x_test_proc,y_test)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000315 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 485
# [LightGBM] [Info] Number of data points in the train set: 262, number of used features: 17
# [LightGBM] [Info] Start training from score 65665.335878
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
model.score(x_proc,y_train)
# Out:
# 0.9226493347738642

# %%
l=[1,1,0,0,0,0,0]
col=[]
for i in range(365):
    col+=[l[i%7]]

# %%
data['Week_day']=col

# %%
data['serial']=[i for i in range(365)]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Piligrims', 'Tonsures', 'Hundi', 'Speciality',
#        'Temperature', 'Condition', 'ttd online darshan tickets', 'Tirupati',
#        'Tirumala', 'VIP darshan', 'How to reach Tirupati',
#        'ttd sarva darshan tickets',
#        'ttd free darshan online booking availability',
#        'apsrtc tirumala darshan tickets', 'apsrtc ttd 300 tickets',
#        'ksrtc tirupati package', 'srinivasam complex',
#        'tirumala darshan tickets', 'tirumala darshan',
#        'tirupati balaji.ap.gov.in', 'tirupati darshan 500 rupees ticket',
#        'ttd free darshan online booking availability.1', 'Week_day', 'Review',
#        'Timestamp', 'serial'],
#       dtype='object')

# %%
x_train,x_test,y_train,y_test=train_test_split(data[['Temperature', 'ttd online darshan tickets', 'Tirupati',
       'Tirumala', 'VIP darshan', 'How to reach Tirupati',
       'ttd sarva darshan tickets',
       'ttd free darshan online booking availability','Week_day']],data['Piligrims'],test_size=0.27,random_state=43)

# %%
model=lgb.LGBMRegressor()
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000242 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 235
# [LightGBM] [Info] Number of data points in the train set: 266, number of used features: 9
# [LightGBM] [Info] Start training from score 64456.969925
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
model.score(x_train,y_train)
# Out:
# 0.9024159804416565

# %%
data
# Out:
#      Unnamed: 0        Date  Piligrims  Tonsures  Hundi  Speciality  \
# 0             0  2022-01-01      36560     14084   2.15           5
# 1             1  2022-02-01      38894     12270   3.93           4
# 2             2  2022-03-01      31776     16046   2.69           5
# 3             3  2022-04-01      31523     14692   2.45           4
# 4             4  2022-05-01      32044     17558   2.61           5
# ..          ...         ...        ...       ...    ...         ...
# 360         360  27/12/2022      70496     25500   5.88           0
# 361         361  28/12/2022      71299     28288   3.26           0
# 362         362  29/12/2022      67156     24752   4.92           0
# 363         363  30/12/2022      63253     24490   5.16           0
# 364         364  31/12/2022      71069     34741   4.98           0
#
#      Temperature  Condition  ttd online darshan tickets  Tirupati  ...  \
# 0             77       1275                           0        43  ...
# ...

# %%
df=pd.read_csv('Bit_File_1.csv')

# %%
data['Timestamp']=df['Timestamp']

# %%
df
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        Date     Timestamp  \
# 0               0             0           0  01/01/2022  1.640975e+09
# 1               1             1           1  02/01/2022  1.641062e+09
# 2               2             2           2  03/01/2022  1.641148e+09
# 3               3             3           3  04/01/2022  1.641235e+09
# 4               4             4           4  05/01/2022  1.641321e+09
# ..            ...           ...         ...         ...           ...
# 360           360           360         360  27/12/2022  1.672079e+09
# 361           361           361         361  28/12/2022  1.672166e+09
# 362           362           362         362  29/12/2022  1.672252e+09
# 363           363           363         363  30/12/2022  1.672339e+09
# 364           364           364         364  31/12/2022  1.672425e+09
#
#      Piligrims  Tonsures  Hundi  \
# 0        36560     14084   2.15
# 1        38894     12270   3.93
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(data[['Temperature', 'ttd online darshan tickets', 'Tirupati',
       'Tirumala', 'VIP darshan', 'How to reach Tirupati',
       'ttd sarva darshan tickets',
       'ttd free darshan online booking availability','Week_day','Review']],data['Piligrims'],test_size=0.27,random_state=43)

# %%
df.loc[2,'Review']=0

# %%
#data.drop(['Time_Variant','serial'],axis=1,inplace=True)

# %%
data
# Out:
#      Unnamed: 0        Date  Piligrims  Tonsures  Hundi  Speciality  \
# 0             0  2022-01-01      36560     14084   2.15           5
# 1             1  2022-02-01      38894     12270   3.93           4
# 2             2  2022-03-01      31776     16046   2.69           5
# 3             3  2022-04-01      31523     14692   2.45           4
# 4             4  2022-05-01      32044     17558   2.61           5
# ..          ...         ...        ...       ...    ...         ...
# 360         360  27/12/2022      70496     25500   5.88           0
# 361         361  28/12/2022      71299     28288   3.26           0
# 362         362  29/12/2022      67156     24752   4.92           0
# 363         363  30/12/2022      63253     24490   5.16           0
# 364         364  31/12/2022      71069     34741   4.98           0
#
#      Temperature  Condition  ttd online darshan tickets  Tirupati  ...  \
# 0             77       1275                           0        43  ...
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(data[['Temperature', 'ttd online darshan tickets', 'Tirupati',
       'Tirumala', 'VIP darshan', 'How to reach Tirupati',
       'ttd sarva darshan tickets',
       'ttd free darshan online booking availability','Week_day','Timestamp','Review']],data['Piligrims'],test_size=0.27,random_state=42)

# %%
model=lgb.LGBMRegressor()
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.8171829840109686

# %%
model.score(x_train,y_train)
# Out:
# 0.9360118711361018

# %%
data.to_csv('Final_data.csv')
